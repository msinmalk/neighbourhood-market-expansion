# %%
# %load improved_find_data_start_row\(file_path\).py
from openpyxl import load_workbook
import pandas as pd

def improved_find_data_start_row(file_path):
    """
    Improved version to find the data start row in an Excel file.
    This version scans the first sheet to find the likely start of the data based on a heuristic that considers
    both the number of non-empty cells in a row and the consistency of data types in the row.
    """
    workbook = load_workbook(filename=file_path, read_only=True)
    sheet = workbook.worksheets[0]  # Assuming data is in the first sheet
    
    min_filled_cells = 2  # Minimum number of non-empty cells to consider a row as potential data start
    likely_data_start_row = 0
    consecutive_data_like_rows = 0
    
    for i, row in enumerate(sheet.iter_rows(values_only=True)):
        # Count non-empty cells and types of data in the row
        non_empty_cells = [cell for cell in row if cell is not None]
        filled_cells = len(non_empty_cells)
        data_types = {type(cell) for cell in non_empty_cells}
        
        # Check for a row with enough filled cells and more than one type of data (mixed types suggest data row)
        if filled_cells >= min_filled_cells and len(data_types) > 1:
            consecutive_data_like_rows += 1
        else:
            consecutive_data_like_rows = 0  # Reset if the row doesn't seem like a data row
        
        # If we find 2 consecutive rows that look like data, it's likely the start of the data
        if consecutive_data_like_rows >= 2:
            likely_data_start_row = i - 2  # Adjusting for 0-based index and to include the first data-like row
            break
    
    return likely_data_start_row

def improved_load_excel_with_autodetect(file_path):
    """
    Load an Excel file into a pandas DataFrame, attempting to auto-detect the start of the actual data using
    an improved mechanism.
    """
    start_row = improved_find_data_start_row(file_path)
    df = pd.read_excel(file_path, sheet_name=0, skiprows=start_row)
    df.dropna(axis=1, how='all', inplace=True)
    return df

def load_all_sheets_with_data_start_detection(file_path):
    """
    Load all sheets from an Excel workbook, applying an improved mechanism to detect
    the start of actual data in each sheet.
    
    :param file_path: Path to the Excel workbook.
    :return: A dictionary of DataFrames, one for each sheet, with data start auto-detected.
    """
    # Load all sheets into a dictionary of DataFrames
    all_sheets = pd.read_excel(file_path, sheet_name=None, header=None)
    
    # Apply the improved data start detection mechanism to each sheet
    for sheet_name, df in all_sheets.items():
        # Find the likely data start row using the improved mechanism
        start_row = improved_find_data_start_row(file_path)
        # Reload the sheet with detected start row, if there is meaningful data to skip
        if start_row > 0:
            all_sheets[sheet_name] = pd.read_excel(file_path, sheet_name=sheet_name, skiprows=start_row)
    
    return all_sheets

# %%
financial_data=improved_load_excel_with_autodetect("/Users/myself/Desktop/Walmart USA Serching for Growth/walmartHistoricalFinancials.xlsx")
financial_data=financial_data.dropna()
financial_data=financial_data.fillna(0)

# %%
# Correctly identify and assign unique years to each financial data column
# Assuming the first column after 'Financial Metric' is the most recent year (2021) and decrement for each column after

number_of_years = financial_data.shape[1] - 1  # Total columns minus the 'Financial Metric' column
base_year = 2021
years = [str(base_year - i) for i in range(number_of_years)]

# Map the new year labels to the columns
financial_data.columns = ['Financial Metric'] + years

financial_data['Financial Metric']
# Out:
# 0                               Non-current assets
# 1                              ∟ Intangible assets
# 2                          ∟ Tangible fixed assets
# 3                       ∟ Other non-current assets
# 4                                   Current assets
# 5                                          ∟ Stock
# 6                                        ∟ Debtors
# 7                           ∟ Other current assets
# 8              ∟ Of which cash and cash equivalent
# 9                                     Total assets
# 12                              Shareholders funds
# 13                                       ∟ Capital
# 14                      ∟ Other shareholders funds
# 15                         Non-current liabilities
# 16                                ∟ Long term debt
# 17                 ∟ Other non-current liabilities
# 18                           ∟ Of which provisions
# 19                             Current liabilities
# 20                       ∟ Loans & short-term debt
# 21                                     ∟ Creditors
# 22                     ∟ Other current liabilities
# 23       Total shareholders' funds and liabilities
# 26                               ∟ Working capital
# 27                            ∟ Net current assets
# 28                              ∟ Enterprise value
# 29                           ∟ Number of employees
# 32                  ∟ Operating revenue (Turnover)
# 33                                         ∟ Sales
# 34                           ∟ Costs of goods sold
# 35                                  ∟ Gross profit
# 36              ∟ Other operating expense (income)
# 37                ∟ Operating profit (loss) [EBIT]
# 38                       ∟ Financial profit (loss)
# 39                             ∟ Financial revenue
# 40                            ∟ Financial expenses
# 41                ∟ Profit (loss) before tax [PBT]
# 42                 ∟ Income tax expenses (benefit)
# 43                 ∟ Profit (loss) after tax [PAT]
# 44         ∟ Net extraordinary revenues (expenses)
# 45                        ∟ Extraordinary revenues
# 46                        ∟ Extraordinary expenses
# 47     ∟ Profit (loss) for the period [Net income]
# 50                                ∟ Export revenue
# 51                                ∟ Material costs
# 52                            ∟ Costs of employees
# 53                   ∟ Depreciation & Amortization
# 54                         ∟ Other operating items
# 55                                 ∟ Interest paid
# 56               ∟ Research & Development expenses
# 57             ∟ Cash flow [Net Income before D&A]
# 58                                   ∟ Added value
# 59                                        ∟ EBITDA
# Name: Financial Metric, dtype: object

# %%
import numpy as np

financial_data['Financial Metric']=financial_data['Financial Metric'].str.replace('∟', '', regex=True)
financial_data.replace('\xa0', '', regex=True, inplace=True)
financial_data.replace('n.a.', np.nan, inplace=True)

financial_data=financial_data.dropna(thresh=3)
financial_data
# Out:
#                                Financial Metric          2021          2020  \
# 0                            Non-current assets  1.624290e+08  1.746890e+08
# 1                             Intangible assets  2.898300e+07  3.107300e+07
# 2                         Tangible fixed assets  1.098480e+08  1.270490e+08
# 3                      Other non-current assets  2.359800e+07  1.656700e+07
# 4                                Current assets  9.006700e+07  6.180600e+07
# 5                                         Stock  4.494900e+07  4.443500e+07
# 6                                       Debtors  6.516000e+06  6.284000e+06
# 7                          Other current assets  3.860200e+07  1.108700e+07
# 8             Of which cash and cash equivalent  1.774100e+07  9.465000e+06
# 9                                  Total assets  2.524960e+08  2.364950e+08
# 12                           Shareholders funds  8.092500e+07  7.466900e+07
# 13                                      Capital  2.820000e+05  2.840000e+05
# 14                     Other shareholders funds  8.064300e+07  7.438500e+07
# 15                      Non-current liabilities  7.892600e+07  8.403600e+07
# 16                               Long term debt  4.504100e+07  4.802100e+07
# 17                Other non-current liabilities  3.388500e+07  3.601500e+07
# 19                          Current liabilities  9.264500e+07  7.779000e+07
# 20                      Loans & short-term debt  3.606000e+06  5.873000e+06
# 21                                    Creditors  4.914100e+07  4.697300e+07
# 22                    Other current liabilities  3.989800e+07  2.494400e+07
# 23    Total shareholders' funds and liabilities  2.524960e+08  2.364950e+08
# 26                              Working capital  2.324000e+06  3.746000e+06
# 27                           Net current assets -2.578000e+06 -1.598400e+07
# 28                             Enterprise value  4.286168e+08  3.698325e+08
# 52          NaN          NaN          NaN          NaN          NaN
# 53    2868000.0    2375000.0    1872000.0    1634000.0    1463000.0
# 54   31550000.0   27040000.0   22363000.0   19358000.0   16946000.0
# 55    1383000.0    1022000.0     797000.0     784000.0     845000.0
# 57    9163000.0    7752000.0    6302000.0    5160000.0    4519000.0
# 58          NaN          NaN          NaN          NaN          NaN
# 59   14179000.0   12480000.0    9992000.0    8137000.0    7185000.0
#
#           1996        1995
# 0   20210000.0  17481000.0
# 1          0.0         0.0
# 2   18894000.0  15874000.0
# 3    1316000.0   1607000.0
# 4   17331000.0  15338000.0
# 5   15989000.0  14064000.0
# 6     853000.0    700000.0
# 7     489000.0    574000.0
# 8      83000.0     45000.0
# 9   37541000.0  32819000.0
# 12  14756000.0  12726000.0
# 13    229000.0    230000.0
# 14  14527000.0  12496000.0
# 15  11331000.0  10120000.0
# 16  10600000.0   9709000.0
# 17    731000.0    411000.0
# 19  11454000.0   9973000.0
# 20    340000.0     87000.0
# 21   6442000.0   5907000.0
# 22   4672000.0   3979000.0
# 23  37541000.0  32819000.0
# 26  10400000.0   8857000.0
# 27   5877000.0   5365000.0
# 28         NaN         NaN
# 29    675000.0    622000.0
# 32  94773000.0  83412000.0
# 33  94773000.0  83412000.0
# 34  73201000.0  64516000.0
# 35  21572000.0  18896000.0
# 36  16325000.0  13928000.0
# 37   5247000.0   4968000.0
# 38   -888000.0   -706000.0
# 39         NaN         NaN
# 40    888000.0    706000.0
# 41   4359000.0   4262000.0
# 42   1606000.0   1581000.0
# 43   2753000.0   2681000.0
# 44    -13000.0         0.0
# 47   2740000.0   2681000.0
# 52         NaN         NaN
# 53   1304000.0   1070000.0
# 54  15021000.0  12858000.0
# 55    888000.0    706000.0
# 57   4044000.0   3751000.0
# 58         NaN         NaN
# 59   6551000.0   6038000.0
#
# [46 rows x 28 columns]

# %%
df = financial_data.copy()

if df.index.name != 'Financial Metric':
    dfcopy=df
    df.set_index('Financial Metric', inplace=True)  # Setting 'Financial Metric' as index

df.index=df.index.str.strip()

# Determine categories based on keyword presence or row structure
assets = [metric for metric in df.index if "asset" in metric.lower()]
liabilities_and_equity = [metric for metric in df.index if "liabilit" in metric.lower() or "equity" in metric.lower() or "fund" in metric.lower()]
p_and_l = [metric for metric in df.index if metric not in assets and metric not in liabilities_and_equity]

# Example to show categorized lists
print("Assets:", assets)
print("Liabilities & Equity:", liabilities_and_equity)
print("P&L Items:", p_and_l)
# Out:
# Assets: ['Non-current assets', 'Intangible assets', 'Tangible fixed assets', 'Other non-current assets', 'Current assets', 'Other current assets', 'Total assets', 'Net current assets']
# Liabilities & Equity: ['Shareholders funds', 'Other shareholders funds', 'Non-current liabilities', 'Other non-current liabilities', 'Current liabilities', 'Other current liabilities', "Total shareholders' funds and liabilities"]
# P&L Items: ['Stock', 'Debtors', 'Of which cash and cash equivalent', 'Capital', 'Long term debt', 'Loans & short-term debt', 'Creditors', 'Working capital', 'Enterprise value', 'Number of employees', 'Operating revenue (Turnover)', 'Sales', 'Costs of goods sold', 'Gross profit', 'Other operating expense (income)', 'Operating profit (loss) [EBIT]', 'Financial profit (loss)', 'Financial revenue', 'Financial expenses', 'Profit (loss) before tax [PBT]', 'Income tax expenses (benefit)', 'Profit (loss) after tax [PAT]', 'Net extraordinary revenues (expenses)', 'Profit (loss) for the period [Net income]', 'Costs of employees', 'Depreciation & Amortization', 'Other operating items', 'Interest paid', 'Cash flow [Net Income before D&A]', 'Added value', 'EBITDA']

# %%
# Create a base mapping dictionary
base_mapping = {}

# Map assets to 'Total assets'
for item in assets:
    base_mapping[item] = 'Total assets'

# Map liabilities and equity to 'Total shareholders' funds and liabilities'
for item in liabilities_and_equity:
    base_mapping[item] = 'Total shareholders\' funds and liabilities'

# Map P&L items to 'Sales' (this could be adjusted to 'Operating revenue' if more appropriate)
for item in p_and_l:
    if 'Revenue' in item or 'Sales' in item:
        base_mapping[item] = 'Sales'
    else:
        base_mapping[item] = 'Sales'  # or 'Total operating revenue' if defined in your dataset

# Print or return the base mapping
base_mapping.items()
# Out:
# dict_items([('Non-current assets', 'Total assets'), ('Intangible assets', 'Total assets'), ('Tangible fixed assets', 'Total assets'), ('Other non-current assets', 'Total assets'), ('Current assets', 'Total assets'), ('Other current assets', 'Total assets'), ('Total assets', 'Total assets'), ('Net current assets', 'Total assets'), ('Shareholders funds', "Total shareholders' funds and liabilities"), ('Other shareholders funds', "Total shareholders' funds and liabilities"), ('Non-current liabilities', "Total shareholders' funds and liabilities"), ('Other non-current liabilities', "Total shareholders' funds and liabilities"), ('Current liabilities', "Total shareholders' funds and liabilities"), ('Other current liabilities', "Total shareholders' funds and liabilities"), ("Total shareholders' funds and liabilities", "Total shareholders' funds and liabilities"), ('Stock', 'Sales'), ('Debtors', 'Sales'), ('Of which cash and cash equivalent', 'Sales'), ('Capital', 'Sales'), ('Long term debt', 'Sales'), ('Loans & short-term debt', 'Sales'), ('Creditors', 'Sales'), ('Working capital', 'Sales'), ('Enterprise value', 'Sales'), ('Number of employees', 'Sales'), ('Operating revenue (Turnover)', 'Sales'), ('Sales', 'Sales'), ('Costs of goods sold', 'Sales'), ('Gross profit', 'Sales'), ('Other operating expense (income)', 'Sales'), ('Operating profit (loss) [EBIT]', 'Sales'), ('Financial profit (loss)', 'Sales'), ('Financial revenue', 'Sales'), ('Financial expenses', 'Sales'), ('Profit (loss) before tax [PBT]', 'Sales'), ('Income tax expenses (benefit)', 'Sales'), ('Profit (loss) after tax [PAT]', 'Sales'), ('Net extraordinary revenues (expenses)', 'Sales'), ('Profit (loss) for the period [Net income]', 'Sales'), ('Costs of employees', 'Sales'), ('Depreciation & Amortization', 'Sales'), ('Other operating items', 'Sales'), ('Interest paid', 'Sales'), ('Cash flow [Net Income before D&A]', 'Sales'), ('Added value', 'Sales'), ('EBITDA', 'Sales')])

# %%
# import pandas as pd
# from sklearn.linear_model import LinearRegression
# import numpy as np



# # Calculate historical ratios
# historical_ratios = {}
# for metric, base in base_mapping.items():
#     historical_ratios[metric] = financial_data[metric] / financial_data[base]

# # Perform regression and forecast future ratios
# future_bases = {'Sales': 600000000, 'Total assets': 270000000}  # example forecasted bases
# forecasts = {}
# for metric, ratios in historical_ratios.items():
#     model = LinearRegression()
#     X = np.array(df.columns[1:].astype(int)).reshape(-1, 1)  # Years as independent variable
#     y = ratios.values.reshape(-1, 1)
#     model.fit(X, y)
#     projected_ratio = model.predict(np.array([[2022]]))  # Example future year
#     forecasts[metric] = projected_ratio * future_bases[base_mapping[metric]]

# # Output the forecasted values
# forecasts

# %%
df.index.name
df.columns
# Out:
# Index(['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995'],
#       dtype='object')

# %% [markdown]
# ## Forecast Base Financial Metrics with Assumed YOY Rates

# %%
# Define the growth assumptions based on the details provided earlier
assumptions = {
    'Sales': {'type': 'YOY', 'rates': [0.0814, 0.0392, 0.0261, 0.0244, 0.0237, 0.0238]},
    'Costs of goods sold': {'type': '% of revenue', 'rates': [0.7541, 0.7513, 0.7513, 0.7513, 0.7513, 0.7513]},
    'Gross profit': {'type': 'direct', 'rates': None},  # Calculated directly as difference
    'Operating and SG&A costs': {'type': '% of sales', 'rates': [0.1863, 0.1834, 0.1834, 0.1834, 0.1834, 0.1834]}
}

# Base year for forecast
base_year = '2021'
forecast_years = ['2022F','2023F', '2024F', '2025F', '2026F', '2027F']

# Initialize a DataFrame to hold the forecasted values
forecast_df = pd.DataFrame(index=df.index, columns=forecast_years)

# Iterate over each forecast year and apply the assumptions to calculate forecast values
for idx, year in enumerate(forecast_years):
    if 'Sales' in assumptions:
        if idx == 0:  # First forecast year, base it on the last historical year
            last_sales = df.loc[df.index.str.contains("Sales"), base_year].values[0]
        growth_rate = assumptions['Sales']['rates'][idx]
        forecast_sales = last_sales * (1 + growth_rate)
        forecast_df.loc['Sales', year] = forecast_sales
        last_sales = forecast_sales  # Update for next year's calculation

    if 'Costs of goods sold' in assumptions:
        cost_rate = assumptions['Costs of goods sold']['rates'][idx]
        forecast_costs = forecast_sales * cost_rate
        forecast_df.loc['Costs of goods sold', year] = forecast_costs

    if 'Gross profit' in assumptions:
        forecast_gross_profit = forecast_sales - forecast_costs
        forecast_df.loc['Gross profit', year] = forecast_gross_profit

    if 'Operating and SG&A costs' in assumptions:
        sgna_rate = assumptions['Operating and SG&A costs']['rates'][idx]
        forecast_sgna = forecast_sales * sgna_rate
        forecast_df.loc['Operating and SG&A costs', year] = forecast_sgna

# Calculate CAGR for the forecast period
cagr_df = (forecast_df[forecast_years].astype(float).iloc[:, -1] / forecast_df[forecast_years].astype(float).iloc[:, 0]) ** (1 / (len(forecast_years) - 1)) - 1
forecast_df.loc[:, 'CAGR'] = cagr_df

# Display the forecast results
forecast_df, cagr_df
# Out:
# (                                                     2022F             2023F  \
#  Financial Metric
#  Non-current assets                                     NaN               NaN
#  Intangible assets                                      NaN               NaN
#  Tangible fixed assets                                  NaN               NaN
#  Other non-current assets                               NaN               NaN
#  Current assets                                         NaN               NaN
#  Stock                                                  NaN               NaN
#  Debtors                                                NaN               NaN
#  Other current assets                                   NaN               NaN
#  Of which cash and cash equivalent                      NaN               NaN
#  Total assets                                           NaN               NaN
#  Shareholders funds                                     NaN               NaN
#  Capital                                                NaN               NaN
#  Other shareholders funds                               NaN               NaN
#  Non-current liabilities                                NaN               NaN
#  Long term debt                                         NaN               NaN
#  Other non-current liabilities                          NaN               NaN
#  Current liabilities                                    NaN               NaN
#  Loans & short-term debt                                NaN               NaN
#  Creditors                                              NaN               NaN
#  Other current liabilities                              NaN               NaN
#  Total shareholders' funds and liabilities              NaN               NaN
#  Working capital                                        NaN               NaN
#  Net current assets                                     NaN               NaN
#  Enterprise value                                       NaN               NaN
#  Number of employees                                    NaN               NaN
#  Operating revenue (Turnover)                           NaN               NaN
#  Sales                                          604665891.4   628368794.34288
#  Costs of goods sold                        455978548.70474  472093475.189806
#  Gross profit                               148687342.69526  156275319.153074
#  Other operating expense (income)                       NaN               NaN
#  Operating profit (loss) [EBIT]                         NaN               NaN
#  Financial profit (loss)                                NaN               NaN
#  Financial revenue                                      NaN               NaN
#  Financial expenses                                     NaN               NaN
#  Profit (loss) before tax [PBT]                         NaN               NaN
#  Income tax expenses (benefit)                          NaN               NaN
#  Profit (loss) after tax [PAT]                          NaN               NaN
#  Net extraordinary revenues (expenses)                  NaN               NaN
#  Profit (loss) for the period [Net income]              NaN               NaN
#  Costs of employees                                     NaN               NaN
#  Depreciation & Amortization                            NaN               NaN
#  Other operating items                                  NaN               NaN
#  Interest paid                                          NaN               NaN
#  Cash flow [Net Income before D&A]                      NaN               NaN
#  Added value                                            NaN               NaN
#  EBITDA                                                 NaN               NaN
#  Operating and SG&A costs                   112649255.56782  115242836.882484
#
#                                                        2024F             2025F  \
#  Financial Metric
#  Non-current assets                                      NaN               NaN
#  Intangible assets                                       NaN               NaN
#  Tangible fixed assets                                   NaN               NaN
#  Other non-current assets                                NaN               NaN
#  Current assets                                          NaN               NaN
#  Stock                                                   NaN               NaN
#  Debtors                                                 NaN               NaN
#  Other current assets                                    NaN               NaN
#  Of which cash and cash equivalent                       NaN               NaN
#  Total assets                                            NaN               NaN
#  Shareholders funds                                      NaN               NaN
#  Capital                                                 NaN               NaN
#  Other shareholders funds                                NaN               NaN
#  Non-current liabilities                                 NaN               NaN
#  Long term debt                                          NaN               NaN
#  Other non-current liabilities                           NaN               NaN
#  Current liabilities                                     NaN               NaN
#  Loans & short-term debt                                 NaN               NaN
#  Creditors                                               NaN               NaN
#  Other current liabilities                               NaN               NaN
#  Total shareholders' funds and liabilities               NaN               NaN
#  Working capital                                         NaN               NaN
#  Net current assets                                      NaN               NaN
#  Enterprise value                                        NaN               NaN
#  Number of employees                                     NaN               NaN
#  Operating revenue (Turnover)                            NaN               NaN
#  Sales                                      644769219.875229  660501588.840185
#  Costs of goods sold                         484415114.89226  496234843.695631
#  Gross profit                                160354104.98297  164266745.144554
#  Other operating expense (income)                        NaN               NaN
#  Operating profit (loss) [EBIT]                          NaN               NaN
#  Financial profit (loss)                                 NaN               NaN
#  Financial revenue                                       NaN               NaN
#  Financial expenses                                      NaN               NaN
#  Profit (loss) before tax [PBT]                          NaN               NaN
#  Income tax expenses (benefit)                           NaN               NaN
#  Profit (loss) after tax [PAT]                           NaN               NaN
#  Net extraordinary revenues (expenses)                   NaN               NaN
#  Profit (loss) for the period [Net income]               NaN               NaN
#  Costs of employees                                      NaN               NaN
#  Depreciation & Amortization                             NaN               NaN
#  Other operating items                                   NaN               NaN
#  Interest paid                                           NaN               NaN
#  Cash flow [Net Income before D&A]                       NaN               NaN
#  Added value                                             NaN               NaN
#  EBITDA                                                  NaN               NaN
#  Operating and SG&A costs                   118250674.925117   121135991.39329
#
#                                                        2026F             2027F  \
#  Financial Metric
#  Non-current assets                                      NaN               NaN
#  Intangible assets                                       NaN               NaN
#  Tangible fixed assets                                   NaN               NaN
#  Other non-current assets                                NaN               NaN
#  Current assets                                          NaN               NaN
#  Stock                                                   NaN               NaN
#  Debtors                                                 NaN               NaN
#  Other current assets                                    NaN               NaN
#  Of which cash and cash equivalent                       NaN               NaN
#  Total assets                                            NaN               NaN
#  Shareholders funds                                      NaN               NaN
#  Capital                                                 NaN               NaN
#  Other shareholders funds                                NaN               NaN
#  Non-current liabilities                                 NaN               NaN
#  Long term debt                                          NaN               NaN
#  Other non-current liabilities                           NaN               NaN
#  Current liabilities                                     NaN               NaN
#  Loans & short-term debt                                 NaN               NaN
#  Creditors                                               NaN               NaN
#  Other current liabilities                               NaN               NaN
#  Total shareholders' funds and liabilities               NaN               NaN
#  Working capital                                         NaN               NaN
#  Net current assets                                      NaN               NaN
#  Enterprise value                                        NaN               NaN
#  Number of employees                                     NaN               NaN
#  Operating revenue (Turnover)                            NaN               NaN
#  Sales                                      676155476.495697  692247976.836295
#  Costs of goods sold                        507995609.491217  520085904.997108
#  Gross profit                                168159867.00448  172162071.839187
#  Other operating expense (income)                        NaN               NaN
#  Operating profit (loss) [EBIT]                          NaN               NaN
#  Financial profit (loss)                                 NaN               NaN
#  Financial revenue                                       NaN               NaN
#  Financial expenses                                      NaN               NaN
#  Profit (loss) before tax [PBT]                          NaN               NaN
#  Income tax expenses (benefit)                           NaN               NaN
#  Profit (loss) after tax [PAT]                           NaN               NaN
#  Net extraordinary revenues (expenses)                   NaN               NaN
#  Profit (loss) for the period [Net income]               NaN               NaN
#  Costs of employees                                      NaN               NaN
#  Depreciation & Amortization                             NaN               NaN
#  Other operating items                                   NaN               NaN
#  Interest paid                                           NaN               NaN
#  Cash flow [Net Income before D&A]                       NaN               NaN
#  Added value                                             NaN               NaN
#  EBITDA                                                  NaN               NaN
#  Operating and SG&A costs                   124006914.389311  126958278.951776
#
#                                                 CAGR
#  Financial Metric
#  Non-current assets                              NaN
#  Intangible assets                               NaN
#  Tangible fixed assets                           NaN
#  Other non-current assets                        NaN
#  Current assets                                  NaN
#  Stock                                           NaN
#  Debtors                                         NaN
#  Other current assets                            NaN
#  Of which cash and cash equivalent               NaN
#  Total assets                                    NaN
#  Shareholders funds                              NaN
#  Capital                                         NaN
#  Other shareholders funds                        NaN
#  Non-current liabilities                         NaN
#  Long term debt                                  NaN
#  Other non-current liabilities                   NaN
#  Current liabilities                             NaN
#  Loans & short-term debt                         NaN
#  Creditors                                       NaN
#  Other current liabilities                       NaN
#  Total shareholders' funds and liabilities       NaN
#  Working capital                                 NaN
#  Net current assets                              NaN
#  Enterprise value                                NaN
#  Number of employees                             NaN
#  Operating revenue (Turnover)                    NaN
#  Sales                                      0.027423
#  Costs of goods sold                        0.026659
#  Gross profit                               0.029752
#  Other operating expense (income)                NaN
#  Operating profit (loss) [EBIT]                  NaN
#  Financial profit (loss)                         NaN
#  Financial revenue                               NaN
#  Financial expenses                              NaN
#  Profit (loss) before tax [PBT]                  NaN
#  Income tax expenses (benefit)                   NaN
#  Profit (loss) after tax [PAT]                   NaN
#  Net extraordinary revenues (expenses)           NaN
#  Profit (loss) for the period [Net income]       NaN
#  Costs of employees                              NaN
#  Depreciation & Amortization                     NaN
#  Other operating items                           NaN
#  Interest paid                                   NaN
#  Cash flow [Net Income before D&A]               NaN
#  Added value                                     NaN
#  EBITDA                                          NaN
#  Operating and SG&A costs                   0.024204  ,
#  Financial Metric
#  Non-current assets                                NaN
#  Intangible assets                                 NaN
#  Tangible fixed assets                             NaN
#  Other non-current assets                          NaN
#  Current assets                                    NaN
#  Stock                                             NaN
#  Debtors                                           NaN
#  Other current assets                              NaN
#  Of which cash and cash equivalent                 NaN
#  Total assets                                      NaN
#  Shareholders funds                                NaN
#  Capital                                           NaN
#  Other shareholders funds                          NaN
#  Non-current liabilities                           NaN
#  Long term debt                                    NaN
#  Other non-current liabilities                     NaN
#  Current liabilities                               NaN
#  Loans & short-term debt                           NaN
#  Creditors                                         NaN
#  Other current liabilities                         NaN
#  Total shareholders' funds and liabilities         NaN
#  Working capital                                   NaN
#  Net current assets                                NaN
#  Enterprise value                                  NaN
#  Number of employees                               NaN
#  Operating revenue (Turnover)                      NaN
#  Sales                                        0.027423
#  Costs of goods sold                          0.026659
#  Gross profit                                 0.029752
#  Other operating expense (income)                  NaN
#  Operating profit (loss) [EBIT]                    NaN
#  Financial profit (loss)                           NaN
#  Financial revenue                                 NaN
#  Financial expenses                                NaN
#  Profit (loss) before tax [PBT]                    NaN
#  Income tax expenses (benefit)                     NaN
#  Profit (loss) after tax [PAT]                     NaN
#  Net extraordinary revenues (expenses)             NaN
#  Profit (loss) for the period [Net income]         NaN
#  Costs of employees                                NaN
#  Depreciation & Amortization                       NaN
#  Other operating items                             NaN
#  Interest paid                                     NaN
#  Cash flow [Net Income before D&A]                 NaN
#  Added value                                       NaN
#  EBITDA                                            NaN
#  Operating and SG&A costs                     0.024204
#  dtype: float64)

# %%
# # # Define growth assumptions based on the details provided earlier
# assumptions = {
#     'Sales': {'type': 'YOY', 'rates': [0.0814, 0.0392, 0.0261, 0.0244, 0.0237, 0.0238]},
#     'Costs of goods sold': {'type': '% of revenue', 'rates': [0.7541, 0.7513, 0.7513, 0.7513, 0.7513, 0.7513]},
#     'Gross profit': {'type': 'direct', 'rates': None},  # Calculated directly as difference
#     'Operating and SG&A costs': {'type': '% of sales', 'rates': [0.1863, 0.1834, 0.1834, 0.1834, 0.1834, 0.1834]}
# }

# # # # Calculate future bases from assumptions
# # base_year = '2021'
# # forecast_years = ['2022F', '2023F', '2024F', '2025F', '2026F', '2027F']
# # last_values = df[base_year]

# # for year in forecast_years:
# #     for metric, config in assumptions.items():
# #         if config['type'] == 'YOY':
# #             growth_rate = config['rates'][int(year[:4]) - 2022]
# #             forecast_value = last_values[metric] * (1 + growth_rate)
# #         elif config['type'] == '% of revenue':
# #             revenue_based_rate = config['rates'][int(year[:4]) - 2022]
# #             forecast_value = forecast_df.loc['Sales', year] * revenue_based_rate
# #         elif config['type'] == 'direct':
# #             forecast_value = forecast_df.loc['Sales', year] - forecast_df.loc['Costs of goods sold', year]
# #         forecast_df.loc[metric, year] = forecast_value
# #         last_values[metric] = forecast_value

# %% [markdown]
# ## Handle NaNs

# %%
df = df.T

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler



# Assuming df is your DataFrame loaded with data

# Identify columns with missing values
cols_with_missing = df.columns[df.isnull().any()].tolist()

# Decide on an imputation strategy for each column
# Example: Use mean for numerical data and a model for 'Costs of employees'
imputation_strategies = {
    col: ('mean' if df[col].dtype.kind in 'biufc' else 'most_frequent')
    for col in cols_with_missing if col != 'Costs of employees'
}
imputation_strategies['Costs of employees'] = 'model'  # Deciding to use a model for 'Costs of employees'

# Apply imputation or model prediction
for col, strategy in imputation_strategies.items():
    if strategy != 'model':
        # Simple imputation
        imputer = SimpleImputer(strategy=strategy)
        df[col] = imputer.fit_transform(df[[col]])
    else:
        # Setup for predictive modeling
        # Assuming you've already identified features to use
        features = df.columns.difference([col, 'SomeOtherColumnToExclude']).tolist()
        train_data = df.dropna(subset=[col] + features)
        target = train_data[col]
        train_features = train_data[features]

        # Scaling features
        scaler = StandardScaler()
        train_features_scaled = scaler.fit_transform(train_features)
        
        # Model fitting
        model = RandomForestRegressor(random_state=0)
        model.fit(train_features_scaled, target)
        
        # Predicting missing values
        test_features = df.loc[df[col].isnull(), features]
        test_features_scaled = scaler.transform(test_features)
        predicted_values = model.predict(test_features_scaled)
        
        # Fill in the missing values
        df.loc[df[col].isnull(), col] = predicted_values

print("Missing values handled for columns:", cols_with_missing)
print(df.info())
# Out:
# Missing values handled for columns: ['Enterprise value', 'Financial revenue', 'Costs of employees', 'Added value']
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 2021 to 1995
# Data columns (total 46 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Non-current assets                         27 non-null     float64
#  1   Intangible assets                          27 non-null     float64
#  2   Tangible fixed assets                      27 non-null     float64
#  3   Other non-current assets                   27 non-null     float64
#  4   Current assets                             27 non-null     float64
#  5   Stock                                      27 non-null     float64
#  6   Debtors                                    27 non-null     float64
#  7   Other current assets                       27 non-null     float64
#  8   Of which cash and cash equivalent          27 non-null     float64
#  9   Total assets                               27 non-null     float64
#  10  Shareholders funds                         27 non-null     float64
#  11  Capital                                    27 non-null     float64
#  12  Other shareholders funds                   27 non-null     float64
#  13  Non-current liabilities                    27 non-null     float64
#  14  Long term debt                             27 non-null     float64
#  15  Other non-current liabilities              27 non-null     float64
#  16  Current liabilities                        27 non-null     float64
#  17  Loans & short-term debt                    27 non-null     float64
#  18  Creditors                                  27 non-null     float64
#  19  Other current liabilities                  27 non-null     float64
#  20  Total shareholders' funds and liabilities  27 non-null     float64
#  21  Working capital                            27 non-null     float64
#  22  Net current assets                         27 non-null     float64
#  23  Enterprise value                           27 non-null     float64
#  24  Number of employees                        27 non-null     float64
#  25  Operating revenue (Turnover)               27 non-null     float64
#  26  Sales                                      27 non-null     float64
#  27  Costs of goods sold                        27 non-null     float64
#  28  Gross profit                               27 non-null     float64
#  29  Other operating expense (income)           27 non-null     float64
#  30  Operating profit (loss) [EBIT]             27 non-null     float64
#  31  Financial profit (loss)                    27 non-null     float64
#  32  Financial revenue                          27 non-null     float64
#  33  Financial expenses                         27 non-null     float64
#  34  Profit (loss) before tax [PBT]             27 non-null     float64
#  35  Income tax expenses (benefit)              27 non-null     float64
#  36  Profit (loss) after tax [PAT]              27 non-null     float64
#  37  Net extraordinary revenues (expenses)      27 non-null     float64
#  38  Profit (loss) for the period [Net income]  27 non-null     float64
#  39  Costs of employees                         27 non-null     float64
#  40  Depreciation & Amortization                27 non-null     float64
#  41  Other operating items                      27 non-null     float64
#  42  Interest paid                              27 non-null     float64
#  43  Cash flow [Net Income before D&A]          27 non-null     float64
#  44  Added value                                27 non-null     float64
#  45  EBITDA                                     27 non-null     float64
# dtypes: float64(46)
# memory usage: 11.0+ KB
# None

# %%
df['Costs of employees']
# Out:
# 2021    1169000.0
# 2020     854000.0
# 2019     773000.0
# 2018     626000.0
# 2017     596000.0
# 2016     448000.0
# 2015     462000.0
# 2014     555630.0
# 2013     560940.0
# 2012     559340.0
# 2011     554940.0
# 2010     561220.0
# 2009     565370.0
# 2008     567220.0
# 2007     578580.0
# 2006     571510.0
# 2005     570030.0
# 2004     575430.0
# 2003     573940.0
# 2002     584410.0
# 2001     577340.0
# 2000     568090.0
# 1999     578680.0
# 1998     614930.0
# 1997     614930.0
# 1996     613450.0
# 1995     614930.0
# Name: Costs of employees, dtype: float64

# %% [markdown]
# ## Forecast all values on Historical Data

# %%
df = df.T
df
# Out:
#                                                    2021          2020  \
# Financial Metric
# Non-current assets                         1.624290e+08  1.746890e+08
# Intangible assets                          2.898300e+07  3.107300e+07
# Tangible fixed assets                      1.098480e+08  1.270490e+08
# Other non-current assets                   2.359800e+07  1.656700e+07
# Current assets                             9.006700e+07  6.180600e+07
# Stock                                      4.494900e+07  4.443500e+07
# Debtors                                    6.516000e+06  6.284000e+06
# Other current assets                       3.860200e+07  1.108700e+07
# Of which cash and cash equivalent          1.774100e+07  9.465000e+06
# Total assets                               2.524960e+08  2.364950e+08
# Shareholders funds                         8.092500e+07  7.466900e+07
# Capital                                    2.820000e+05  2.840000e+05
# Other shareholders funds                   8.064300e+07  7.438500e+07
# Non-current liabilities                    7.892600e+07  8.403600e+07
# Long term debt                             4.504100e+07  4.802100e+07
# Other non-current liabilities              3.388500e+07  3.601500e+07
# Current liabilities                        9.264500e+07  7.779000e+07
# Loans & short-term debt                    3.606000e+06  5.873000e+06
# Creditors                                  4.914100e+07  4.697300e+07
# Other current liabilities                  3.989800e+07  2.494400e+07
# Total shareholders' funds and liabilities  2.524960e+08  2.364950e+08
# Working capital                            2.324000e+06  3.746000e+06
# Net current assets                        -2.578000e+06 -1.598400e+07
# Enterprise value                           4.286168e+08  3.698325e+08
# Number of employees                        2.300000e+06  2.200000e+06
# Profit (loss) after tax [PAT]              7.621000e+06  1.032300e+07
# Net extraordinary revenues (expenses)     -9.510000e+05 -4.610000e+05
# Profit (loss) for the period [Net income]  6.670000e+06  9.862000e+06
# Costs of employees                         7.730000e+05  6.260000e+05
# Depreciation & Amortization                1.070000e+07  1.052900e+07
# Other operating items                      1.063740e+08  1.058840e+08
# Interest paid                              2.346000e+06  2.330000e+06
# Cash flow [Net Income before D&A]          1.737000e+07  2.039100e+07
# Added value                                2.432800e+07  2.814700e+07
# EBITDA                                     3.265700e+07  3.096600e+07
#
#                                                    2017          2016  \
# Financial Metric
# Non-current assets                         1.411360e+08  1.393420e+08
# Intangible assets                          1.703700e+07  1.669500e+07
# Tangible fixed assets                      1.141780e+08  1.165160e+08
# Other non-current assets                   9.921000e+06  6.131000e+06
# Current assets                             5.768900e+07  6.023900e+07
# Stock                                      4.304600e+07  4.446900e+07
# Debtors                                    5.835000e+06  5.624000e+06
# Other current assets                       8.808000e+06  1.014600e+07
# Of which cash and cash equivalent          6.602000e+06  8.343000e+06
# Total assets                               1.988250e+08  1.995810e+08
# Shareholders funds                         7.779800e+07  8.054600e+07
# Capital                                    3.050000e+05  3.170000e+05
# Other shareholders funds                   7.749300e+07  8.022900e+07
# Non-current liabilities                    5.409900e+07  5.441600e+07
# Long term debt                             3.880900e+07  4.403000e+07
# Other non-current liabilities              1.529000e+07  1.038600e+07
# Current liabilities                        6.692800e+07  6.461900e+07
# Loans & short-term debt                    2.821000e+06  3.296000e+06
# Creditors                                  4.143300e+07  3.848700e+07
# Other current liabilities                  2.267400e+07  2.283600e+07
# Total shareholders' funds and liabilities  1.988250e+08  1.995810e+08
# Working capital                            7.448000e+06  1.160600e+07
# Net current assets                        -9.239000e+06 -4.380000e+06
# Enterprise value                           2.412319e+08  2.541689e+08
# Number of employees                        2.300000e+06  2.300000e+06
# Operating revenue (Turnover)               4.858730e+08  4.821300e+08
# Sales                                      4.858730e+08  4.821300e+08
# Costs of goods sold                        3.511760e+08  3.515300e+08
# Gross profit                               1.346970e+08  1.306000e+08
# Other operating expense (income)           1.119330e+08  1.064950e+08
# Operating profit (loss) [EBIT]             2.276400e+07  2.410500e+07
# Financial profit (loss)                   -2.267000e+06 -2.467000e+06
# Financial revenue                          1.000000e+05  8.100000e+04
# Financial expenses                         2.367000e+06  2.548000e+06
# Profit (loss) before tax [PBT]             2.049700e+07  2.163800e+07
# Income tax expenses (benefit)              6.204000e+06  6.558000e+06
# Profit (loss) after tax [PAT]              1.429300e+07  1.508000e+07
# Net extraordinary revenues (expenses)     -6.500000e+05 -3.860000e+05
# Profit (loss) for the period [Net income]  1.364300e+07  1.469400e+07
# Costs of employees                         5.960000e+05  4.480000e+05
# Depreciation & Amortization                1.008000e+07  9.454000e+06
# Other operating items                      1.012570e+08  9.659300e+07
# Interest paid                              2.367000e+06  2.548000e+06
# Cash flow [Net Income before D&A]          2.372300e+07  2.414800e+07
# Added value                                3.289000e+07  3.370200e+07
# EBITDA                                     3.284400e+07  3.355900e+07
#
#                                                    2015          2014  \
# Financial Metric
# Non-current assets                         1.402120e+08  1.435660e+08
# Intangible assets                          1.810200e+07  1.951000e+07
# Tangible fixed assets                      1.166550e+08  1.179070e+08
# Other non-current assets                   5.455000e+06  6.149000e+06
# Current assets                             6.327800e+07  6.118500e+07
# Stock                                      4.514100e+07  4.485800e+07
# Debtors                                    6.778000e+06  6.677000e+06
# Other current assets                       1.135900e+07  9.650000e+06
# Of which cash and cash equivalent          9.135000e+06  6.627000e+06
# Total assets                               2.034900e+08  2.047510e+08
# Shareholders funds                         8.139400e+07  7.625500e+07
# Capital                                    3.230000e+05  3.230000e+05
# Other shareholders funds                   8.107100e+07  7.593200e+07
# Non-current liabilities                    5.684300e+07  5.915100e+07
# Long term debt                             4.349500e+07  4.455900e+07
# Other non-current liabilities              1.334800e+07  1.459200e+07
# Current liabilities                        6.525300e+07  6.934500e+07
# Loans & short-term debt                    5.078000e+06  4.412000e+06
# Creditors                                  3.841000e+07  3.741500e+07
# Other current liabilities                  2.176500e+07  2.751800e+07
# Total shareholders' funds and liabilities  2.034900e+08  2.047510e+08
# Working capital                            1.350900e+07  1.412000e+07
# Net current assets                        -1.975000e+06 -8.160000e+06
# Enterprise value                           3.149370e+08  2.916617e+08
# Number of employees                        2.200000e+06  2.200000e+06
# Operating revenue (Turnover)               4.856510e+08  4.762940e+08
# Sales                                      4.856510e+08  4.762940e+08
# Costs of goods sold                        3.559130e+08  3.491990e+08
# Gross profit                               1.297380e+08  1.270950e+08
# Other operating expense (income)           1.025910e+08  1.002230e+08
# Operating profit (loss) [EBIT]             2.714700e+07  2.687200e+07
# Financial profit (loss)                   -2.348000e+06 -2.216000e+06
# Financial revenue                          1.130000e+05  1.190000e+05
# Financial expenses                         2.461000e+06  2.335000e+06
# Profit (loss) before tax [PBT]             2.479900e+07  2.465600e+07
# Income tax expenses (benefit)              7.985000e+06  8.105000e+06
# Profit (loss) after tax [PAT]              1.681400e+07  1.655100e+07
# Net extraordinary revenues (expenses)     -4.510000e+05 -5.290000e+05
# Profit (loss) for the period [Net income]  1.636300e+07  1.602200e+07
# Costs of employees                         4.620000e+05  5.556300e+05
# Depreciation & Amortization                9.173000e+06  8.870000e+06
# Other operating items                      9.295600e+07  9.135300e+07
# Interest paid                              2.461000e+06  2.335000e+06
# Cash flow [Net Income before D&A]          2.553600e+07  2.489200e+07
# Added value                                3.644400e+07  3.211600e+07
# EBITDA                                     3.632000e+07  3.574200e+07
#
#                                                    2013          2012  ...  \
# Financial Metric                                                       ...
# Non-current assets                         1.431650e+08  1.384310e+08  ...
# Intangible assets                          2.049700e+07  2.065100e+07  ...
# Tangible fixed assets                      1.166810e+08  1.123240e+08  ...
# Other non-current assets                   5.987000e+06  5.456000e+06  ...
# Current assets                             5.994000e+07  5.497500e+07  ...
# Stock                                      4.380300e+07  4.071400e+07  ...
# Debtors                                    6.768000e+06  5.937000e+06  ...
# Other current assets                       9.369000e+06  8.324000e+06  ...
# Of which cash and cash equivalent          7.066000e+06  6.003000e+06  ...
# Total assets                               2.031050e+08  1.934060e+08  ...
# Shareholders funds                         7.634300e+07  7.131500e+07  ...
# Capital                                    3.320000e+05  3.420000e+05  ...
# Other shareholders funds                   7.601100e+07  7.097300e+07  ...
# Non-current liabilities                    5.494400e+07  5.979100e+07  ...
# Long term debt                             4.141700e+07  4.707900e+07  ...
# Other non-current liabilities              1.352700e+07  1.271200e+07  ...
# Current liabilities                        7.181800e+07  6.230000e+07  ...
# Loans & short-term debt                    5.914000e+06  2.301000e+06  ...
# Creditors                                  3.808000e+07  3.660800e+07  ...
# Other current liabilities                  2.782400e+07  2.339100e+07  ...
# Total shareholders' funds and liabilities  2.031050e+08  1.934060e+08  ...
# Working capital                            1.249100e+07  1.004300e+07  ...
# Net current assets                        -1.187800e+07 -7.325000e+06  ...
# Enterprise value                           2.810696e+08  2.575637e+08  ...
# Number of employees                        2.200000e+06  2.200000e+06  ...
# Operating revenue (Turnover)               4.686510e+08  4.465090e+08  ...
# Sales                                      4.686510e+08  4.465090e+08  ...
# Costs of goods sold                        3.437960e+08  3.268630e+08  ...
# Gross profit                               1.248550e+08  1.196460e+08  ...
# Other operating expense (income)           9.713000e+07  9.315500e+07  ...
# Operating profit (loss) [EBIT]             2.772500e+07  2.649100e+07  ...
# Financial profit (loss)                   -2.063000e+06 -2.159000e+06  ...
# Financial revenue                          1.860000e+05  1.610000e+05  ...
# Financial expenses                         2.249000e+06  2.320000e+06  ...
# Profit (loss) before tax [PBT]             2.566200e+07  2.433200e+07  ...
# Income tax expenses (benefit)              7.958000e+06  7.924000e+06  ...
# Profit (loss) after tax [PAT]              1.770400e+07  1.640800e+07  ...
# Net extraordinary revenues (expenses)     -7.050000e+05 -7.090000e+05  ...
# Profit (loss) for the period [Net income]  1.699900e+07  1.569900e+07  ...
# Costs of employees                         5.609400e+05  5.593400e+05  ...
# Depreciation & Amortization                8.501000e+06  8.130000e+06  ...
# Other operating items                      8.862900e+07  8.502500e+07  ...
# Interest paid                              2.249000e+06  2.320000e+06  ...
# Cash flow [Net Income before D&A]          2.550000e+07  2.382900e+07  ...
# Added value                                3.211600e+07  3.211600e+07  ...
# EBITDA                                     3.622600e+07  3.462100e+07  ...
#
#                                                    2004          2003  \
# Financial Metric
# Non-current assets                         7.098400e+07  6.408600e+07
# Intangible assets                          9.882000e+06  9.389000e+06
# Tangible fixed assets                      5.902300e+07  5.137400e+07
# Other non-current assets                   2.079000e+06  3.323000e+06
# Current assets                             3.442100e+07  3.072200e+07
# Stock                                      2.661200e+07  2.440100e+07
# Debtors                                    1.254000e+06  1.569000e+06
# Other current assets                       6.555000e+06  4.752000e+06
# Of which cash and cash equivalent          5.199000e+06  2.736000e+06
# Total assets                               1.054050e+08  9.480800e+07
# Shareholders funds                         4.362300e+07  3.946100e+07
# Capital                                    4.310000e+05  4.400000e+05
# Other shareholders funds                   4.319200e+07  3.902100e+07
# Non-current liabilities                    2.394200e+07  2.282800e+07
# Long term debt                             2.009900e+07  1.959700e+07
# Other non-current liabilities              3.843000e+06  3.231000e+06
# Current liabilities                        3.784000e+07  3.251900e+07
# Loans & short-term debt                    3.100000e+06  4.712000e+06
# Creditors                                  1.942500e+07  1.682900e+07
# Other current liabilities                  1.531500e+07  1.097800e+07
# Total shareholders' funds and liabilities  1.054050e+08  9.480800e+07
# Working capital                            8.441000e+06  9.141000e+06
# Net current assets                        -3.419000e+06 -1.797000e+06
# Enterprise value                           2.588424e+08  2.380248e+08
# Number of employees                        1.500000e+06  1.400000e+06
# Operating revenue (Turnover)               2.586810e+08  2.315770e+08
# Sales                                      2.586810e+08  2.315770e+08
# Costs of goods sold                        1.948950e+08  1.749350e+08
# Gross profit                               6.378600e+07  5.664200e+07
# Other operating expense (income)           4.876100e+07  4.334700e+07
# Operating profit (loss) [EBIT]             1.502500e+07  1.329500e+07
# Financial profit (loss)                   -8.320000e+05 -9.270000e+05
# Financial revenue                          1.640000e+05  1.320000e+05
# Financial expenses                         9.960000e+05  1.059000e+06
# Profit (loss) before tax [PBT]             1.419300e+07  1.236800e+07
# Income tax expenses (benefit)              5.118000e+06  4.357000e+06
# Profit (loss) after tax [PAT]              9.075000e+06  8.011000e+06
# Net extraordinary revenues (expenses)     -2.100000e+04 -5.600000e+04
# Profit (loss) for the period [Net income]  9.054000e+06  7.955000e+06
# Costs of employees                         5.754300e+05  5.739400e+05
# Depreciation & Amortization                3.852000e+06  3.364000e+06
# Other operating items                      4.490900e+07  3.998300e+07
# Interest paid                              9.960000e+05  1.059000e+06
# Cash flow [Net Income before D&A]          1.290600e+07  1.131900e+07
# Added value                                3.211600e+07  3.211600e+07
# EBITDA                                     1.887700e+07  1.665900e+07
#
#                                                    2002          2001  \
# Financial Metric
# Non-current assets                         5.564900e+07  5.157500e+07
# Intangible assets                          8.566000e+06  9.059000e+06
# Tangible fixed assets                      4.575000e+07  4.093400e+07
# Other non-current assets                   1.333000e+06  1.582000e+06
# Current assets                             2.787800e+07  2.655500e+07
# Stock                                      2.261400e+07  2.144200e+07
# Debtors                                    2.000000e+06  1.768000e+06
# Other current assets                       3.264000e+06  3.345000e+06
# Of which cash and cash equivalent          2.161000e+06  2.054000e+06
# Total assets                               8.352700e+07  7.813000e+07
# Shareholders funds                         3.510200e+07  3.134300e+07
# Capital                                    4.450000e+05  4.470000e+05
# Other shareholders funds                   3.465700e+07  3.089600e+07
# Non-current liabilities                    2.114300e+07  1.783800e+07
# Long term debt                             1.873200e+07  1.565500e+07
# Other non-current liabilities              2.411000e+06  2.183000e+06
# Current liabilities                        2.728200e+07  2.894900e+07
# Loans & short-term debt                    2.405000e+06  4.375000e+06
# Creditors                                  1.561700e+07  1.509200e+07
# Other current liabilities                  9.260000e+06  9.482000e+06
# Total shareholders' funds and liabilities  8.352700e+07  7.813000e+07
# Working capital                            8.997000e+06  8.118000e+06
# Net current assets                         5.960000e+05 -2.394000e+06
# Enterprise value                           2.899713e+08  2.784883e+08
# Number of employees                        1.383000e+06  1.244000e+06
# Operating revenue (Turnover)               2.058230e+08  1.931160e+08
# Sales                                      2.058230e+08  1.931160e+08
# Costs of goods sold                        1.563970e+08  1.473870e+08
# Gross profit                               4.942600e+07  4.572900e+07
# Other operating expense (income)           3.784700e+07  3.441800e+07
# Operating profit (loss) [EBIT]             1.157900e+07  1.131100e+07
# Financial profit (loss)                   -1.183000e+06 -1.195000e+06
# Financial revenue                          1.710000e+05  1.880000e+05
# Financial expenses                         1.354000e+06  1.383000e+06
# Profit (loss) before tax [PBT]             1.039600e+07  1.011600e+07
# Income tax expenses (benefit)              3.765000e+06  3.692000e+06
# Profit (loss) after tax [PAT]              6.631000e+06  6.424000e+06
# Net extraordinary revenues (expenses)     -3.900000e+04 -1.290000e+05
# Profit (loss) for the period [Net income]  6.592000e+06  6.295000e+06
# Costs of employees                         5.844100e+05  5.773400e+05
# Depreciation & Amortization                2.700000e+06  2.868000e+06
# Other operating items                      3.514700e+07  3.155000e+07
# Interest paid                              1.354000e+06  1.383000e+06
# Cash flow [Net Income before D&A]          9.292000e+06  9.163000e+06
# Added value                                3.211600e+07  3.211600e+07
# EBITDA                                     1.427900e+07  1.417900e+07
#
#                                                    2000          1999  \
# Financial Metric
# Non-current assets                         4.599300e+07  2.886400e+07
# Intangible assets                          9.392000e+06  2.538000e+06
# Tangible fixed assets                      3.596900e+07  2.597300e+07
# Other non-current assets                   6.320000e+05  3.530000e+05
# Current assets                             2.435600e+07  2.113200e+07
# Stock                                      1.979300e+07  1.707600e+07
# Debtors                                    1.341000e+06  1.118000e+06
# Other current assets                       3.222000e+06  2.938000e+06
# Of which cash and cash equivalent          1.856000e+06  1.879000e+06
# Total assets                               7.034900e+07  4.999600e+07
# Shareholders funds                         2.583400e+07  2.111200e+07
# Capital                                    4.460000e+05  4.450000e+05
# Other shareholders funds                   2.538800e+07  2.066700e+07
# Non-current liabilities                    1.871200e+07  1.212200e+07
# Long term debt                             1.667400e+07  9.607000e+06
# Other non-current liabilities              2.038000e+06  2.515000e+06
# Current liabilities                        2.580300e+07  1.676200e+07
# Loans & short-term debt                    2.085000e+06  1.006000e+06
# Creditors                                  1.310500e+07  1.025700e+07
# Other current liabilities                  1.061300e+07  5.499000e+06
# Total shareholders' funds and liabilities  7.034900e+07  4.999600e+07
# Working capital                            8.029000e+06  7.937000e+06
# Net current assets                        -1.447000e+06  4.370000e+06
# Enterprise value                           2.784883e+08  2.784883e+08
# Number of employees                        1.140000e+06  9.100000e+05
# Operating revenue (Turnover)               1.668090e+08  1.392080e+08
# Sales                                      1.668090e+08  1.392080e+08
# Costs of goods sold                        1.272890e+08  1.068530e+08
# Gross profit                               3.952000e+07  3.235500e+07
# Other operating expense (income)           2.941500e+07  2.423500e+07
# Operating profit (loss) [EBIT]             1.010500e+07  8.120000e+06
# Financial profit (loss)                   -1.022000e+06 -7.970000e+05
# Financial revenue                          1.807143e+05  1.807143e+05
# Financial expenses                         1.022000e+06  7.970000e+05
# Profit (loss) before tax [PBT]             9.083000e+06  7.323000e+06
# Income tax expenses (benefit)              3.338000e+06  2.740000e+06
# Profit (loss) after tax [PAT]              5.745000e+06  4.583000e+06
# Net extraordinary revenues (expenses)     -3.680000e+05 -1.530000e+05
# Profit (loss) for the period [Net income]  5.377000e+06  4.430000e+06
# Costs of employees                         5.680900e+05  5.786800e+05
# Depreciation & Amortization                2.375000e+06  1.872000e+06
# Other operating items                      2.704000e+07  2.236300e+07
# Interest paid                              1.022000e+06  7.970000e+05
# Cash flow [Net Income before D&A]          7.752000e+06  6.302000e+06
# Added value                                3.211600e+07  3.211600e+07
# EBITDA                                     1.248000e+07  9.992000e+06
#
#                                                    1998          1997  \
# Financial Metric
# Non-current assets                         2.603200e+07  2.161100e+07
# Intangible assets                          0.000000e+00  0.000000e+00
# Tangible fixed assets                      2.360600e+07  2.032400e+07
# Other non-current assets                   2.426000e+06  1.287000e+06
# Current assets                             1.935200e+07  1.799300e+07
# Stock                                      1.649700e+07  1.589700e+07
# Debtors                                    9.760000e+05  8.450000e+05
# Other current assets                       1.879000e+06  1.251000e+06
# Of which cash and cash equivalent          1.447000e+06  8.830000e+05
# Total assets                               4.538400e+07  3.960400e+07
# Shareholders funds                         1.850300e+07  1.714300e+07
# Capital                                    2.240000e+05  2.280000e+05
# Other shareholders funds                   1.827900e+07  1.691500e+07
# Non-current liabilities                    1.242100e+07  1.150400e+07
# Long term debt                             9.674000e+06  1.001600e+07
# Other non-current liabilities              2.747000e+06  1.488000e+06
# Current liabilities                        1.446000e+07  1.095700e+07
# Loans & short-term debt                    1.141000e+06  6.180000e+05
# Creditors                                  9.126000e+06  7.628000e+06
# Other current liabilities                  4.193000e+06  2.711000e+06
# Total shareholders' funds and liabilities  4.538400e+07  3.960400e+07
# Working capital                            8.347000e+06  9.114000e+06
# Net current assets                         4.892000e+06  7.036000e+06
# Enterprise value                           2.784883e+08  2.784883e+08
# Number of employees                        8.250000e+05  7.280000e+05
# Operating revenue (Turnover)               1.192990e+08  1.061780e+08
# Sales                                      1.192990e+08  1.061780e+08
# Costs of goods sold                        9.180400e+07  8.204700e+07
# Gross profit                               2.749500e+07  2.413100e+07
# Other operating expense (income)           2.099200e+07  1.840900e+07
# Operating profit (loss) [EBIT]             6.503000e+06  5.722000e+06
# Financial profit (loss)                   -7.840000e+05 -8.450000e+05
# Financial revenue                          1.807143e+05  1.807143e+05
# Financial expenses                         7.840000e+05  8.450000e+05
# Profit (loss) before tax [PBT]             5.719000e+06  4.877000e+06
# Income tax expenses (benefit)              2.115000e+06  1.794000e+06
# Profit (loss) after tax [PAT]              3.604000e+06  3.083000e+06
# Net extraordinary revenues (expenses)     -7.800000e+04 -2.700000e+04
# Profit (loss) for the period [Net income]  3.526000e+06  3.056000e+06
# Costs of employees                         6.149300e+05  6.149300e+05
# Depreciation & Amortization                1.634000e+06  1.463000e+06
# Other operating items                      1.935800e+07  1.694600e+07
# Interest paid                              7.840000e+05  8.450000e+05
# Cash flow [Net Income before D&A]          5.160000e+06  4.519000e+06
# Added value                                3.211600e+07  3.211600e+07
# EBITDA                                     8.137000e+06  7.185000e+06
#
#                                                    1996          1995
# Financial Metric
# Non-current assets                         2.021000e+07  1.748100e+07
# Intangible assets                          0.000000e+00  0.000000e+00
# Tangible fixed assets                      1.889400e+07  1.587400e+07
# Other non-current assets                   1.316000e+06  1.607000e+06
# Current assets                             1.733100e+07  1.533800e+07
# Stock                                      1.598900e+07  1.406400e+07
# Debtors                                    8.530000e+05  7.000000e+05
# Other current assets                       4.890000e+05  5.740000e+05
# Of which cash and cash equivalent          8.300000e+04  4.500000e+04
# Total assets                               3.754100e+07  3.281900e+07
# Shareholders funds                         1.475600e+07  1.272600e+07
# Capital                                    2.290000e+05  2.300000e+05
# Other shareholders funds                   1.452700e+07  1.249600e+07
# Non-current liabilities                    1.133100e+07  1.012000e+07
# Long term debt                             1.060000e+07  9.709000e+06
# Other non-current liabilities              7.310000e+05  4.110000e+05
# Current liabilities                        1.145400e+07  9.973000e+06
# Loans & short-term debt                    3.400000e+05  8.700000e+04
# Creditors                                  6.442000e+06  5.907000e+06
# Other current liabilities                  4.672000e+06  3.979000e+06
# Total shareholders' funds and liabilities  3.754100e+07  3.281900e+07
# Working capital                            1.040000e+07  8.857000e+06
# Net current assets                         5.877000e+06  5.365000e+06
# Enterprise value                           2.784883e+08  2.784883e+08
# Number of employees                        6.750000e+05  6.220000e+05
# Operating revenue (Turnover)               9.477300e+07  8.341200e+07
# Sales                                      9.477300e+07  8.341200e+07
# Costs of goods sold                        7.320100e+07  6.451600e+07
# Gross profit                               2.157200e+07  1.889600e+07
# Other operating expense (income)           1.632500e+07  1.392800e+07
# Operating profit (loss) [EBIT]             5.247000e+06  4.968000e+06
# Financial profit (loss)                   -8.880000e+05 -7.060000e+05
# Financial revenue                          1.807143e+05  1.807143e+05
# Financial expenses                         8.880000e+05  7.060000e+05
# Profit (loss) before tax [PBT]             4.359000e+06  4.262000e+06
# Income tax expenses (benefit)              1.606000e+06  1.581000e+06
# Profit (loss) after tax [PAT]              2.753000e+06  2.681000e+06
# Net extraordinary revenues (expenses)     -1.300000e+04  0.000000e+00
# Profit (loss) for the period [Net income]  2.740000e+06  2.681000e+06
# Costs of employees                         6.134500e+05  6.149300e+05
# Depreciation & Amortization                1.304000e+06  1.070000e+06
# Other operating items                      1.502100e+07  1.285800e+07
# Interest paid                              8.880000e+05  7.060000e+05
# Cash flow [Net Income before D&A]          4.044000e+06  3.751000e+06
# Added value                                3.211600e+07  3.211600e+07
# EBITDA                                     6.551000e+06  6.038000e+06
#
# [46 rows x 27 columns]

# %%
from sklearn.linear_model import LinearRegression

# Forecast years and base year definition
forecast_years = ['2022F', '2023F', '2024F', '2025F', '2026F', '2027F']
historical_years = df.columns[df.columns.str.isnumeric()]

# Forecast function
def forecast_metric(values, years, forecast_years):
    years_reshaped = years.values.reshape(-1, 1)
    values_reshaped = values.values.reshape(-1, 1)
    model = LinearRegression()
    model.fit(years_reshaped, values_reshaped)
    future_years = pd.Series(forecast_years).str[:-1].astype(int).values.reshape(-1, 1)
    predictions = model.predict(future_years).flatten()
    return pd.Series(predictions, index=forecast_years)

# Apply forecasting
forecasted_values = df.apply(lambda x: forecast_metric(x, historical_years, forecast_years), axis=1)
cagr_values = (forecasted_values[forecast_years].astype(float).iloc[:, -1] / forecasted_values[forecast_years].astype(float).iloc[:, 0]) ** (1 / (len(forecast_years) - 1)) - 1
# Print results
forecasted_values,cagr_values
# Out:
# (                                                  2022F         2023F  \
#  Other current liabilities                  3.760639e+07  3.870734e+07
#  Total shareholders' funds and liabilities  2.954796e+08  3.039906e+08
#  Working capital                            6.594812e+06  6.490697e+06
#  Net current assets                        -1.691164e+07 -1.759938e+07
#  Enterprise value                           3.247791e+08  3.273508e+08
#  Number of employees                        2.971322e+06  3.040455e+06
#  Operating revenue (Turnover)               6.836175e+08  7.028764e+08
#  Sales                                      6.836175e+08  7.028764e+08
#  Costs of goods sold                        4.965422e+08  5.103184e+08
#  Gross profit                               1.870753e+08  1.925580e+08
#  Other operating expense (income)           1.537369e+08  1.583712e+08
#  Operating profit (loss) [EBIT]             3.333840e+07  3.418685e+07
#  Financial profit (loss)                   -5.125841e+06 -5.293857e+06
#  Financial revenue                          1.500000e+05  1.482937e+05
#  Financial expenses                         5.360792e+06  5.534053e+06
#  Profit (loss) before tax [PBT]             2.821256e+07  2.889300e+07
#  Income tax expenses (benefit)              8.649801e+06  8.838668e+06
#  Profit (loss) after tax [PAT]              1.956276e+07  2.005433e+07
#  Net extraordinary revenues (expenses)     -7.129544e+05 -7.328305e+05
#  Profit (loss) for the period [Net income]  1.884981e+07  1.932150e+07
#  Costs of employees                         7.199933e+05  7.260652e+05
#  Depreciation & Amortization                1.381856e+07  1.425199e+07
#  Other operating items                      1.391601e+08  1.433290e+08
#  Interest paid                              3.148051e+06  3.226906e+06
#  Cash flow [Net Income before D&A]          3.266837e+07  3.357348e+07
#  Added value                                3.198804e+07  3.198094e+07
#  EBITDA                                     4.715696e+07  4.843884e+07  ,
#  Financial Metric
#  Non-current assets                           0.031550
#  Intangible assets                            0.034432
#  Tangible fixed assets                        0.030235
#  Other non-current assets                     0.039358
#  Current assets                               0.028348
#  Stock                                        0.025303
#  Debtors                                      0.034065
#  Other current assets                         0.034689
#  Of which cash and cash equivalent            0.033844
#  Total assets                                 0.030621
#  Shareholders funds                           0.028867
#  Capital                                     -0.004484
#  Other shareholders funds                     0.028976
#  Non-current liabilities                      0.032407
#  Long term debt                               0.029201
#  Other non-current liabilities                0.039338
#  Current liabilities                          0.030938
#  Loans & short-term debt                      0.023149
#  Creditors                                    0.031601
#  Other current liabilities                    0.031156
#  Total shareholders' funds and liabilities    0.030621
#  Working capital                             -0.015311
#  Net current assets                           0.044438
#  Enterprise value                             0.008047
#  Number of employees                          0.024431
#  Operating revenue (Turnover)                 0.029907
#  Sales                                        0.029907
#  Costs of goods sold                          0.029424
#  Gross profit                                 0.031192
#  Other operating expense (income)             0.032143
#  Operating profit (loss) [EBIT]               0.026853
#  Financial profit (loss)                      0.035163
#  Financial revenue                           -0.011125
#  Financial expenses                           0.034635
#  Profit (loss) before tax [PBT]               0.025373
#  Income tax expenses (benefit)                0.022856
#  Profit (loss) after tax [PAT]                0.026494
#  Net extraordinary revenues (expenses)        0.029576
#  Profit (loss) for the period [Net income]    0.026378
#  Costs of employees                           0.008579
#  Depreciation & Amortization                  0.033539
#  Other operating items                        0.031930
#  Interest paid                                0.026406
#  Cash flow [Net Income before D&A]            0.029382
#  Added value                                 -0.000222
#  EBITDA                                       0.028793
#  dtype: float64)

# %% [markdown]
# ## Forecast Using Ratios of Non Base Financial Metrics to Base Metrics

# %%
# from sklearn.linear_model import LinearRegression
# import numpy as np
# #Assuming 'financial_data' is your DataFrame
# if df.index.name != 'Financial Metric':
#     dfcopy=df
#     df.set_index('Financial Metric', inplace=True)  # Setting 'Financial Metric' as index

# # Calculate historical ratios
# historical_ratios = {}
# for metric, base in base_mapping.items():
#     print(metric,base)
#     if metric in df.index and base in df.index:
#         historical_ratios[metric] = df.loc[metric] / df.loc[base]
# # Example of performing linear regression on one of the metrics

# print(historical_ratios)
# model = LinearRegression()
# if 'Operating profit (loss) [EBIT]' in historical_ratios:
#     ratios = historical_ratios['Operating profit (loss) [EBIT]'].dropna()  # Drop NaN to avoid fitting errors
#     years = np.array([int(year) for year in ratios.index]).reshape(-1, 1)
#     model.fit(years, ratios.values.reshape(-1, 1))
#     # Predict for a future year, e.g., 2022
#     future_year = np.array([[2022]])
#     forecast_ratio = model.predict(future_year)
#     print(f"Forecasted Ratio for 2022: {forecast_ratio[0][0]}")

# # Use similar logic for other metrics

# %%
for metric, ratios in historical_ratios.items():
    print(ratios.index.tolist(), ratios.values.tolist())

# %%
# Now apply these dynamic bases to your regression forecasts
future_bases = {
    'Sales': forecasted_values.loc['Sales'],
    'Total assets': forecasted_values.loc['Total assets']  # Assuming 'Total assets' forecast is calculated similarly
}
print(future_bases)
#Calculate historical ratios for regression
historical_ratios = {}
for metric, base in base_mapping.items():
    historical_ratios[metric] = df.loc[metric] / df.loc[base]

historical_ratios=pd.DataFrame.from_dict(historical_ratios)
historical_ratios=historical_ratios.dropna(axis='columns')


# Perform regression and forecast future ratios
forecasts = {}
projected_ratios = {}

yeardf = pd.DataFrame(df.columns)

for metric, ratios in historical_ratios.items():
    model = LinearRegression()
    X = yeardf
    y = ratios
    model.fit(X, y)


    slope = model.coef_[0]
    intercept = model.intercept_
    print(f"The {metric} model is: Value = {slope:.10f} * Year + {intercept:.5f}")
    
    # Create X and y for model fitting
    for year in forecast_years:
        projected_ratio = model.predict(np.array([[int(year[:-1])]]))  # Forecast each future year
        forecasts[metric, year] = projected_ratio * future_bases[base][year]
        projected_ratios[metric, year] = projected_ratio
        

# # Output the forecasted values
# print(future_bases)
# #forecasts
historical_ratios['Costs of employees'], projected_ratios
# Out:
# {'Sales': 2022F    6.065818e+08
# 2023F    6.258407e+08
# 2024F    6.450997e+08
# 2025F    6.643586e+08
# 2026F    6.836175e+08
# 2027F    7.028764e+08
# Name: Sales, dtype: float64, 'Total assets': 2022F    2.614355e+08
# 2023F    2.699465e+08
# 2024F    2.784575e+08
# 2025F    2.869686e+08
# 2026F    2.954796e+08
# 2027F    3.039906e+08
# Name: Total assets, dtype: float64}
# The Non-current assets model is: Value = 0.0058262648 * Year + -11.03207
# The Intangible assets model is: Value = 0.0032323505 * Year + -6.40610
# The Tangible fixed assets model is: Value = 0.0012995196 * Year + -2.06065
# The Other non-current assets model is: Value = 0.0012943947 * Year + -2.56533
# The Current assets model is: Value = -0.0058262648 * Year + 12.03207
# The Other current assets model is: Value = 0.0014713789 * Year + -2.90143
# The Total assets model is: Value = -0.0000000000 * Year + 1.00000
# The Net current assets model is: Value = -0.0068841673 * Year + 13.81792
# The Shareholders funds model is: Value = -0.0023855724 * Year + 5.17953
# The Other shareholders funds model is: Value = -0.0021377744 * Year + 4.67855
# The Non-current liabilities model is: Value = 0.0013276698 * Year + -2.39368
# The Other non-current liabilities model is: Value = 0.0032633413 * Year + -6.49640
# The Current liabilities model is: Value = 0.0010579026 * Year + -1.78585
# The Other current liabilities model is: Value = 0.0006166845 * Year + -1.11592
# The Total shareholders' funds and liabilities model is: Value = -0.0000000000 * Year + 1.00000
# The Stock model is: Value = -0.0026356334 * Year + 5.39739
# The Debtors model is: Value = 0.0002291088 * Year + -0.45003
# The Of which cash and cash equivalent model is: Value = 0.0004863275 * Year + -0.96176
# The Capital model is: Value = -0.0000942467 * Year + 0.19063
# The Long term debt model is: Value = -0.0003836859 * Year + 0.85995
# The Loans & short-term debt model is: Value = -0.0000583393 * Year + 0.12783
# The Creditors model is: Value = 0.0006394288 * Year + -1.20493
# The Working capital model is: Value = -0.0030459534 * Year + 6.15229
# The Enterprise value model is: Value = -0.0834488970 * Year + 168.70313
# The Number of employees model is: Value = -0.0001242862 * Year + 0.25513
# The Operating revenue (Turnover) model is: Value = -0.0000000000 * Year + 1.00000
# The Sales model is: Value = -0.0000000000 * Year + 1.00000
# The Costs of goods sold model is: Value = -0.0020171768 * Year + 4.79553
# The Gross profit model is: Value = 0.0020171768 * Year + -3.79553
# The Other operating expense (income) model is: Value = 0.0025043702 * Year + -4.82882
# The Operating profit (loss) [EBIT] model is: Value = -0.0004871934 * Year + 1.03329
# The Financial profit (loss) model is: Value = -0.0000580376 * Year + 0.11039
# The Financial revenue model is: Value = -0.0000606651 * Year + 0.12257
# The Financial expenses model is: Value = 0.0000616380 * Year + -0.11723
# The Profit (loss) before tax [PBT] model is: Value = -0.0005452310 * Year + 1.14368
# The Income tax expenses (benefit) model is: Value = -0.0003222530 * Year + 0.66365
# The Profit (loss) after tax [PAT] model is: Value = -0.0002229779 * Year + 0.48003
# The Net extraordinary revenues (expenses) model is: Value = -0.0000182184 * Year + 0.03561
# The Profit (loss) for the period [Net income] model is: Value = -0.0002411963 * Year + 0.51563
# The Costs of employees model is: Value = -0.0001813259 * Year + 0.36659
# The Depreciation & Amortization model is: Value = 0.0003354441 * Year + -0.65687
# The Other operating items model is: Value = 0.0021073198 * Year + -4.04860
# The Interest paid model is: Value = -0.0001183455 * Year + 0.24319
# The Cash flow [Net Income before D&A] model is: Value = 0.0000942478 * Year + -0.14123
# The Added value model is: Value = -0.0102313541 * Year + 20.67729
# The EBITDA model is: Value = -0.0001517493 * Year + 0.37642
# (2021    0.002091
#  2020    0.001630
#  2019    0.001503
#  2018    0.001251
#  2017    0.001227
#  2016    0.000929
#  2015    0.000951
#  2014    0.001167
#  2013    0.001197
#  2012    0.001253
#  2011    0.001315
#  2010    0.001375
#  2009    0.001399
#  2008    0.001504
#  2007    0.001661
#  2006    0.001831
#  2005    0.002005
#  2004    0.002224
#  2003    0.002478
#  2002    0.002839
#  2001    0.002990
#  2000    0.003406
#  1999    0.004157
#  1998    0.005155
#  1997    0.005792
#  1996    0.006473
#  1995    0.007372
#  Name: Costs of employees, dtype: float64,
#  {('Non-current assets', '2022F'): array([0.74863305]),
#   ('Non-current assets', '2023F'): array([0.75445932]),
#   ('Non-current assets', '2024F'): array([0.76028558]),
#   ('Non-current assets', '2025F'): array([0.76611185]),
#   ('Non-current assets', '2026F'): array([0.77193811]),
#   ('Non-current assets', '2027F'): array([0.77776438]),
#   ('Intangible assets', '2022F'): array([0.12971392]),
#   ('Intangible assets', '2023F'): array([0.13294627]),
#   ('Intangible assets', '2024F'): array([0.13617862]),
#   ('Intangible assets', '2025F'): array([0.13941097]),
#   ('Intangible assets', '2026F'): array([0.14264332]),
#   ('Intangible assets', '2027F'): array([0.14587567]),
#   ('Tangible fixed assets', '2022F'): array([0.56698114]),
#   ('Tangible fixed assets', '2023F'): array([0.56828066]),
#   ('Tangible fixed assets', '2024F'): array([0.56958018]),
#   ('Tangible fixed assets', '2025F'): array([0.5708797]),
#   ('Tangible fixed assets', '2026F'): array([0.57217922]),
#   ('Tangible fixed assets', '2027F'): array([0.57347874]),
#   ('Other non-current assets', '2022F'): array([0.05193799]),
#   ('Other non-current assets', '2023F'): array([0.05323238]),
#   ('Other non-current assets', '2024F'): array([0.05452678]),
#   ('Other non-current assets', '2025F'): array([0.05582117]),
#   ('Other non-current assets', '2026F'): array([0.05711557]),
#   ('Other non-current assets', '2027F'): array([0.05840996]),
#   ('Current assets', '2022F'): array([0.25136695]),
#   ('Current assets', '2023F'): array([0.24554068]),
#   ('Current assets', '2024F'): array([0.23971442]),
#   ('Current assets', '2025F'): array([0.23388815]),
#   ('Current assets', '2026F'): array([0.22806189]),
#   ('Current assets', '2027F'): array([0.22223562]),
#   ('Other current assets', '2022F'): array([0.07369581]),
#   ('Other current assets', '2023F'): array([0.07516719]),
#   ('Other current assets', '2024F'): array([0.07663857]),
#   ('Other current assets', '2025F'): array([0.07810995]),
#   ('Other current assets', '2026F'): array([0.07958133]),
#   ('Other current assets', '2027F'): array([0.0810527]),
#   ('Total assets', '2022F'): array([1.]),
#   ('Total assets', '2023F'): array([1.]),
#   ('Total assets', '2024F'): array([1.]),
#   ('Total assets', '2025F'): array([1.]),
#   ('Total assets', '2026F'): array([1.]),
#   ('Total assets', '2027F'): array([1.]),
#   ('Net current assets', '2022F'): array([-0.10186525]),
#   ('Net current assets', '2023F'): array([-0.10874942]),
#   ('Net current assets', '2024F'): array([-0.11563359]),
#   ('Net current assets', '2025F'): array([-0.12251775]),
#   ('Net current assets', '2026F'): array([-0.12940192]),
#   ('Net current assets', '2027F'): array([-0.13628609]),
#   ('Shareholders funds', '2022F'): array([0.35590422]),
#   ('Shareholders funds', '2023F'): array([0.35351865]),
#   ('Shareholders funds', '2024F'): array([0.35113308]),
#   ('Shareholders funds', '2025F'): array([0.3487475]),
#   ('Shareholders funds', '2026F'): array([0.34636193]),
#   ('Shareholders funds', '2027F'): array([0.34397636]),
#   ('Other shareholders funds', '2022F'): array([0.35597176]),
#   ('Other shareholders funds', '2023F'): array([0.35383398]),
#   ('Other shareholders funds', '2024F'): array([0.35169621]),
#   ('Other shareholders funds', '2025F'): array([0.34955843]),
#   ('Other shareholders funds', '2026F'): array([0.34742066]),
#   ('Other shareholders funds', '2027F'): array([0.34528288]),
#   ('Non-current liabilities', '2022F'): array([0.29086358]),
#   ('Non-current liabilities', '2023F'): array([0.29219125]),
#   ('Non-current liabilities', '2024F'): array([0.29351892]),
#   ('Non-current liabilities', '2025F'): array([0.29484659]),
#   ('Non-current liabilities', '2026F'): array([0.29617426]),
#   ('Non-current liabilities', '2027F'): array([0.29750193]),
#   ('Other non-current liabilities', '2022F'): array([0.10207689]),
#   ('Other non-current liabilities', '2023F'): array([0.10534023]),
#   ('Other non-current liabilities', '2024F'): array([0.10860357]),
#   ('Other non-current liabilities', '2025F'): array([0.11186691]),
#   ('Other non-current liabilities', '2026F'): array([0.11513025]),
#   ('Other non-current liabilities', '2027F'): array([0.11839359]),
#   ('Current liabilities', '2022F'): array([0.3532322]),
#   ('Current liabilities', '2023F'): array([0.3542901]),
#   ('Current liabilities', '2024F'): array([0.355348]),
#   ('Current liabilities', '2025F'): array([0.35640591]),
#   ('Current liabilities', '2026F'): array([0.35746381]),
#   ('Current liabilities', '2027F'): array([0.35852171]),
#   ('Other current liabilities', '2022F'): array([0.13101194]),
#   ('Other current liabilities', '2023F'): array([0.13162863]),
#   ('Other current liabilities', '2024F'): array([0.13224531]),
#   ('Other current liabilities', '2025F'): array([0.13286199]),
#   ('Other current liabilities', '2026F'): array([0.13347868]),
#   ('Other current liabilities', '2027F'): array([0.13409536]),
#   ("Total shareholders' funds and liabilities", '2022F'): array([1.]),
#   ("Total shareholders' funds and liabilities", '2023F'): array([1.]),
#   ("Total shareholders' funds and liabilities", '2024F'): array([1.]),
#   ("Total shareholders' funds and liabilities", '2025F'): array([1.]),
#   ("Total shareholders' funds and liabilities", '2026F'): array([1.]),
#   ("Total shareholders' funds and liabilities", '2027F'): array([1.]),
#   ('Stock', '2022F'): array([0.06813578]),
#   ('Stock', '2023F'): array([0.06550015]),
#   ('Stock', '2024F'): array([0.06286452]),
#   ('Stock', '2025F'): array([0.06022888]),
#   ('Stock', '2026F'): array([0.05759325]),
#   ('Stock', '2027F'): array([0.05495762]),
#   ('Debtors', '2022F'): array([0.01322747]),
#   ('Debtors', '2023F'): array([0.01345658]),
#   ('Debtors', '2024F'): array([0.01368569]),
#   ('Debtors', '2025F'): array([0.0139148]),
#   ('Debtors', '2026F'): array([0.01414391]),
#   ('Debtors', '2027F'): array([0.01437302]),
#   ('Of which cash and cash equivalent', '2022F'): array([0.02158981]),
#   ('Of which cash and cash equivalent', '2023F'): array([0.02207614]),
#   ('Of which cash and cash equivalent', '2024F'): array([0.02256247]),
#   ('Of which cash and cash equivalent', '2025F'): array([0.02304879]),
#   ('Of which cash and cash equivalent', '2026F'): array([0.02353512]),
#   ('Of which cash and cash equivalent', '2027F'): array([0.02402145]),
#   ('Capital', '2022F'): array([5.85408914e-05]),
#   ('Capital', '2023F'): array([-3.57058564e-05]),
#   ('Capital', '2024F'): array([-0.00012995]),
#   ('Capital', '2025F'): array([-0.0002242]),
#   ('Capital', '2026F'): array([-0.00031845]),
#   ('Capital', '2027F'): array([-0.00041269]),
#   ('Long term debt', '2022F'): array([0.08413271]),
#   ('Long term debt', '2023F'): array([0.08374902]),
#   ('Long term debt', '2024F'): array([0.08336534]),
#   ('Long term debt', '2025F'): array([0.08298165]),
#   ('Long term debt', '2026F'): array([0.08259796]),
#   ('Long term debt', '2027F'): array([0.08221428]),
#   ('Loans & short-term debt', '2022F'): array([0.00986771]),
#   ('Loans & short-term debt', '2023F'): array([0.00980937]),
#   ('Loans & short-term debt', '2024F'): array([0.00975103]),
#   ('Loans & short-term debt', '2025F'): array([0.00969269]),
#   ('Loans & short-term debt', '2026F'): array([0.00963435]),
#   ('Loans & short-term debt', '2027F'): array([0.00957601]),
#   ('Creditors', '2022F'): array([0.08799311]),
#   ('Creditors', '2023F'): array([0.08863254]),
#   ('Creditors', '2024F'): array([0.08927197]),
#   ('Creditors', '2025F'): array([0.0899114]),
#   ('Creditors', '2026F'): array([0.09055082]),
#   ('Creditors', '2027F'): array([0.09119025]),
#   ('Working capital', '2022F'): array([-0.00662985]),
#   ('Working capital', '2023F'): array([-0.0096758]),
#   ('Working capital', '2024F'): array([-0.01272176]),
#   ('Working capital', '2025F'): array([-0.01576771]),
#   ('Working capital', '2026F'): array([-0.01881366]),
#   ('Working capital', '2027F'): array([-0.02185962]),
#   ('Enterprise value', '2022F'): array([-0.03053979]),
#   ('Enterprise value', '2023F'): array([-0.11398869]),
#   ('Enterprise value', '2024F'): array([-0.19743758]),
#   ('Enterprise value', '2025F'): array([-0.28088648]),
#   ('Enterprise value', '2026F'): array([-0.36433538]),
#   ('Enterprise value', '2027F'): array([-0.44778428]),
#   ('Number of employees', '2022F'): array([0.00382582]),
#   ('Number of employees', '2023F'): array([0.00370154]),
#   ('Number of employees', '2024F'): array([0.00357725]),
#   ('Number of employees', '2025F'): array([0.00345296]),
#   ('Number of employees', '2026F'): array([0.00332868]),
#   ('Number of employees', '2027F'): array([0.00320439]),
#   ('Operating revenue (Turnover)', '2022F'): array([1.]),
#   ('Operating revenue (Turnover)', '2023F'): array([1.]),
#   ('Operating revenue (Turnover)', '2024F'): array([1.]),
#   ('Operating revenue (Turnover)', '2025F'): array([1.]),
#   ('Operating revenue (Turnover)', '2026F'): array([1.]),
#   ('Operating revenue (Turnover)', '2027F'): array([1.]),
#   ('Sales', '2022F'): array([1.]),
#   ('Sales', '2023F'): array([1.]),
#   ('Sales', '2024F'): array([1.]),
#   ('Sales', '2025F'): array([1.]),
#   ('Sales', '2026F'): array([1.]),
#   ('Sales', '2027F'): array([1.]),
#   ('Costs of goods sold', '2022F'): array([0.71680104]),
#   ('Costs of goods sold', '2023F'): array([0.71478386]),
#   ('Costs of goods sold', '2024F'): array([0.71276669]),
#   ('Costs of goods sold', '2025F'): array([0.71074951]),
#   ('Costs of goods sold', '2026F'): array([0.70873233]),
#   ('Costs of goods sold', '2027F'): array([0.70671516]),
#   ('Gross profit', '2022F'): array([0.28319896]),
#   ('Gross profit', '2023F'): array([0.28521614]),
#   ('Gross profit', '2024F'): array([0.28723331]),
#   ('Gross profit', '2025F'): array([0.28925049]),
#   ('Gross profit', '2026F'): array([0.29126767]),
#   ('Gross profit', '2027F'): array([0.29328484]),
#   ('Other operating expense (income)', '2022F'): array([0.23501779]),
#   ('Other operating expense (income)', '2023F'): array([0.23752216]),
#   ('Other operating expense (income)', '2024F'): array([0.24002653]),
#   ('Other operating expense (income)', '2025F'): array([0.2425309]),
#   ('Other operating expense (income)', '2026F'): array([0.24503527]),
#   ('Other operating expense (income)', '2027F'): array([0.24753964]),
#   ('Operating profit (loss) [EBIT]', '2022F'): array([0.04818117]),
#   ('Operating profit (loss) [EBIT]', '2023F'): array([0.04769397]),
#   ('Operating profit (loss) [EBIT]', '2024F'): array([0.04720678]),
#   ('Operating profit (loss) [EBIT]', '2025F'): array([0.04671959]),
#   ('Operating profit (loss) [EBIT]', '2026F'): array([0.04623239]),
#   ('Operating profit (loss) [EBIT]', '2027F'): array([0.0457452]),
#   ('Financial profit (loss)', '2022F'): array([-0.00695816]),
#   ('Financial profit (loss)', '2023F'): array([-0.0070162]),
#   ('Financial profit (loss)', '2024F'): array([-0.00707423]),
#   ('Financial profit (loss)', '2025F'): array([-0.00713227]),
#   ('Financial profit (loss)', '2026F'): array([-0.00719031]),
#   ('Financial profit (loss)', '2027F'): array([-0.00724835]),
#   ('Financial revenue', '2022F'): array([-9.61525537e-05]),
#   ('Financial revenue', '2023F'): array([-0.00015682]),
#   ('Financial revenue', '2024F'): array([-0.00021748]),
#   ('Financial revenue', '2025F'): array([-0.00027815]),
#   ('Financial revenue', '2026F'): array([-0.00033881]),
#   ('Financial revenue', '2027F'): array([-0.00039948]),
#   ('Financial expenses', '2022F'): array([0.00740351]),
#   ('Financial expenses', '2023F'): array([0.00746515]),
#   ('Financial expenses', '2024F'): array([0.00752679]),
#   ('Financial expenses', '2025F'): array([0.00758843]),
#   ('Financial expenses', '2026F'): array([0.00765006]),
#   ('Financial expenses', '2027F'): array([0.0077117]),
#   ('Profit (loss) before tax [PBT]', '2022F'): array([0.04122301]),
#   ('Profit (loss) before tax [PBT]', '2023F'): array([0.04067778]),
#   ('Profit (loss) before tax [PBT]', '2024F'): array([0.04013255]),
#   ('Profit (loss) before tax [PBT]', '2025F'): array([0.03958732]),
#   ('Profit (loss) before tax [PBT]', '2026F'): array([0.03904209]),
#   ('Profit (loss) before tax [PBT]', '2027F'): array([0.03849685]),
#   ('Income tax expenses (benefit)', '2022F'): array([0.01205869]),
#   ('Income tax expenses (benefit)', '2023F'): array([0.01173644]),
#   ('Income tax expenses (benefit)', '2024F'): array([0.01141418]),
#   ('Income tax expenses (benefit)', '2025F'): array([0.01109193]),
#   ('Income tax expenses (benefit)', '2026F'): array([0.01076968]),
#   ('Income tax expenses (benefit)', '2027F'): array([0.01044742]),
#   ('Profit (loss) after tax [PAT]', '2022F'): array([0.02916432]),
#   ('Profit (loss) after tax [PAT]', '2023F'): array([0.02894134]),
#   ('Profit (loss) after tax [PAT]', '2024F'): array([0.02871836]),
#   ('Profit (loss) after tax [PAT]', '2025F'): array([0.02849539]),
#   ('Profit (loss) after tax [PAT]', '2026F'): array([0.02827241]),
#   ('Profit (loss) after tax [PAT]', '2027F'): array([0.02804943]),
#   ('Net extraordinary revenues (expenses)', '2022F'): array([-0.00122983]),
#   ('Net extraordinary revenues (expenses)', '2023F'): array([-0.00124805]),
#   ('Net extraordinary revenues (expenses)', '2024F'): array([-0.00126627]),
#   ('Net extraordinary revenues (expenses)', '2025F'): array([-0.00128448]),
#   ('Net extraordinary revenues (expenses)', '2026F'): array([-0.0013027]),
#   ('Net extraordinary revenues (expenses)', '2027F'): array([-0.00132092]),
#   ('Profit (loss) for the period [Net income]', '2022F'): array([0.02793449]),
#   ('Profit (loss) for the period [Net income]', '2023F'): array([0.0276933]),
#   ('Profit (loss) for the period [Net income]', '2024F'): array([0.0274521]),
#   ('Profit (loss) for the period [Net income]', '2025F'): array([0.0272109]),
#   ('Profit (loss) for the period [Net income]', '2026F'): array([0.02696971]),
#   ('Profit (loss) for the period [Net income]', '2027F'): array([0.02672851]),
#   ('Costs of employees', '2022F'): array([-5.06374483e-05]),
#   ('Costs of employees', '2023F'): array([-0.00023196]),
#   ('Costs of employees', '2024F'): array([-0.00041329]),
#   ('Costs of employees', '2025F'): array([-0.00059462]),
#   ('Costs of employees', '2026F'): array([-0.00077594]),
#   ('Costs of employees', '2027F'): array([-0.00095727]),
#   ('Depreciation & Amortization', '2022F'): array([0.02140026]),
#   ('Depreciation & Amortization', '2023F'): array([0.0217357]),
#   ('Depreciation & Amortization', '2024F'): array([0.02207115]),
#   ('Depreciation & Amortization', '2025F'): array([0.02240659]),
#   ('Depreciation & Amortization', '2026F'): array([0.02274204]),
#   ('Depreciation & Amortization', '2027F'): array([0.02307748]),
#   ('Other operating items', '2022F'): array([0.21240017]),
#   ('Other operating items', '2023F'): array([0.21450749]),
#   ('Other operating items', '2024F'): array([0.21661481]),
#   ('Other operating items', '2025F'): array([0.21872213]),
#   ('Other operating items', '2026F'): array([0.22082945]),
#   ('Other operating items', '2027F'): array([0.22293677]),
#   ('Interest paid', '2022F'): array([0.00389845]),
#   ('Interest paid', '2023F'): array([0.00378011]),
#   ('Interest paid', '2024F'): array([0.00366176]),
#   ('Interest paid', '2025F'): array([0.00354342]),
#   ('Interest paid', '2026F'): array([0.00342507]),
#   ('Interest paid', '2027F'): array([0.00330673]),
#   ('Cash flow [Net Income before D&A]', '2022F'): array([0.04933475]),
#   ('Cash flow [Net Income before D&A]', '2023F'): array([0.049429]),
#   ('Cash flow [Net Income before D&A]', '2024F'): array([0.04952325]),
#   ('Cash flow [Net Income before D&A]', '2025F'): array([0.04961749]),
#   ('Cash flow [Net Income before D&A]', '2026F'): array([0.04971174]),
#   ('Cash flow [Net Income before D&A]', '2027F'): array([0.04980599]),
#   ('Added value', '2022F'): array([-0.01051189]),
#   ('Added value', '2023F'): array([-0.02074325]),
#   ('Added value', '2024F'): array([-0.0309746]),
#   ('Added value', '2025F'): array([-0.04120595]),
#   ('Added value', '2026F'): array([-0.05143731]),
#   ('Added value', '2027F'): array([-0.06166866]),
#   ('EBITDA', '2022F'): array([0.06958143]),
#   ('EBITDA', '2023F'): array([0.06942968]),
#   ('EBITDA', '2024F'): array([0.06927793]),
#   ('EBITDA', '2025F'): array([0.06912618]),
#   ('EBITDA', '2026F'): array([0.06897443]),
#   ('EBITDA', '2027F'): array([0.06882268])})

# %%
# df = financial_data.copy()

# if df.index.name != 'Financial Metric':
#     dfcopy=df
#     df.set_index('Financial Metric', inplace=True)  # Setting 'Financial Metric' as index

# df.index=df.index.str.strip()
# #df.fillna(method='ffill', inplace=True)
# #df.interpolate(method='linear', axis=1, inplace=True)

# # def controlled_gradient_interpolation(df):
# #     # Column-wise linear interpolation
# #     col_interp = df.interpolate(method='linear', axis=0)

# #     # Calculate relative gradients
# #     col_gradients = col_interp.diff().fillna(method='bfill').fillna(method='ffill')
# #     col_gradients /= col_interp  # Normalize gradients by the value
    
# #     # Damping factor
# #     damping_factor = 0.5

# #     # Row-wise linear interpolation
# #     row_interp = df.interpolate(method='linear', axis=1)
    
# #     # Adjust row interpolation with controlled column gradients
# #     for column in df.columns:
# #         if df[column].isna().any():
# #             # Only adjust NaN entries
# #             nan_indices = df[column].index[df[column].isna()]
# #             for idx in nan_indices:
# #                 if idx in row_interp.index:
# #                     known_idx = df[column].notna().idxmax()  # Index of first non-NaN value
# #                     distance = (df.index.get_loc(idx) - df.index.get_loc(known_idx))
# #                     adjustment = col_gradients.at[idx, column] * distance * damping_factor
# #                     row_interp.at[idx, column] += adjustment

# #     return row_interp

# # # Apply the custom function
# # df = controlled_gradient_interpolation(df)



# df.loc['Costs of employees'], df.loc['Number of employees']
# #financial_data
# df = df.T
# df

# %% [markdown]
# ## Time Series Regression

# %% [markdown]
# ## Random Forest

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Assuming df is your DataFrame

# Impute missing values across the DataFrame
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns, index=df.index)

# Print how many were originally missing
print("Missing 'Costs of employees' before imputation:", df['Costs of employees'].isnull().sum())

# Scaling the entire DataFrame
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df.columns, index=df.index)

# Specify the features and target explicitly
features = ['Total assets', 'Sales', 'Operating revenue (Turnover)', 'Added value']  # Example feature set
target = 'Costs of employees'

# Check if there are any missing values left in the target after imputation
print("Missing 'Costs of employees' after imputation:", df_scaled[target].isnull().sum())

# Filter out rows where target is not NaN to train the model
train_data = df_scaled[df_scaled[target].notna()]
X_train = train_data[features]
y_train = train_data[target]

# Fit the model
model = RandomForestRegressor(random_state=0)
model.fit(X_train, y_train)

# Identify rows where the target is NaN to apply predictions
test_data = df_scaled[df_scaled[target].isnull()]
X_test = test_data[features]

# Check how many rows are available for prediction
print("Rows available for prediction:", len(X_test))

# Condition to prevent model prediction error
if not X_test.empty:
    # Predict missing values
    predicted_costs_scaled = model.predict(X_test)

    # Inverse transform the scaled predictions back to original scale
    predicted_costs = scaler.inverse_transform(predicted_costs_scaled.reshape(-1, 1)).flatten()

    # Fill in the missing values in the original DataFrame
    df.loc[df[target].isnull(), target] = predicted_costs
    print("Missing values filled.")
else:
    print("No missing values to fill.")

# %% [markdown]
# ## Costs of employees only

# %%
# import pandas as pd
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.preprocessing import StandardScaler
# from sklearn.impute import SimpleImputer

# # Assuming df is your DataFrame

# # Impute missing values for selected columns only
# columns_to_impute = df.columns.difference(['Costs of employees'])  # All columns except 'Costs of employees'
# imputer = SimpleImputer(strategy='mean')
# df_imputed = df.copy()
# df_imputed[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

# # Scaling the entire DataFrame
# scaler = StandardScaler()
# df_scaled = pd.DataFrame(scaler.fit_transform(df_imputed), columns=df.columns, index=df.index)

# # Specify the features and target explicitly
# features = ['Total assets', 'Sales', 'Operating revenue (Turnover)', 'Added value']  # Example feature set
# target = 'Costs of employees'

# # Filter out rows where target is not NaN to train the model
# train_data = df_scaled[df_scaled[target].notna()]
# X_train = train_data[features]
# y_train = train_data[target]

# # Fit the model
# model = RandomForestRegressor(random_state=0)
# model.fit(X_train, y_train)

# # Identify rows where the target is NaN to apply predictions
# test_data = df_scaled[df_scaled[target].isnull()]
# X_test = test_data[features]

# # Check how many rows are available for prediction
# print("Rows available for prediction:", len(X_test))

# # Predict missing values if available
# if not X_test.empty:
#     predicted_costs_scaled = model.predict(X_test)
#     predicted_costs = scaler.inverse_transform(predicted_costs_scaled.reshape(-1, 1)).flatten()
#     df.loc[df[target].isnull(), target] = predicted_costs
#     print("Missing values filled.")
# else:
#     print("No missing values to fill.")

# %% [markdown]
# ## Model trained NaN fill

# %%
# import pandas as pd
# from sklearn.impute import SimpleImputer
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.preprocessing import StandardScaler

# # Assuming df is your DataFrame loaded with data

# # Identify columns with missing values
# cols_with_missing = df.columns[df.isnull().any()].tolist()

# # Decide on an imputation strategy for each column
# # Example: Use mean for numerical data and a model for 'Costs of employees'
# imputation_strategies = {
#     col: ('model' if df[col].dtype.kind in 'biufc' else 'model')
#     for col in cols_with_missing if col != 'Costs of employees'
# }
# imputation_strategies['Costs of employees'] = 'model'  # Deciding to use a model for 'Costs of employees'

# # Apply imputation or model prediction
# for col, strategy in imputation_strategies.items():
#     if strategy != 'model':
#         # Simple imputation
#         imputer = SimpleImputer(strategy=strategy)
#         df[col] = imputer.fit_transform(df[[col]])
#     else:
#     # Setup for predictive modeling
#     # Assuming you've already identified features to use
#         features = df.columns.difference([col] + cols_with_missing).tolist()

#     # Ensure the current column is not in the features
#         if col in features:
#             features.remove(col)

#     # Filter data to exclude rows where the target or features have missing values
#         training_data = df.dropna(subset=[col] + features)

#     # Prepare target and features
#         train_features = training_data[features]
#         target = training_data[col]

#     # Scaling features
#         scaler = StandardScaler()
#         train_features_scaled = scaler.fit_transform(train_features)

#     # Model fitting
#         model = RandomForestRegressor(random_state=0)
#         model.fit(train_features_scaled, target)

#     # Prepare features for prediction
#         mask = df[col].isnull()  # Rows where the target is missing
#         test_features = df.loc[mask, features]
#         test_features_scaled = scaler.transform(test_features)

#     # Predicting missing values
#         predicted_values = model.predict(test_features_scaled)

#     # Fill in the missing values
#         df.loc[mask, col] = predicted_values


# print("Missing values handled for columns:", cols_with_missing)
# print(df.info())
